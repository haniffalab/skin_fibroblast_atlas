# %% [markdown]
# # needs 190gb RAM

# %%
import pandas as pd
import scanpy as sc
import matplotlib.pyplot as plt

# %%
sc.settings.figdir = "fig6"
sc.settings.verbosity=0 # verbosity: errors (0), warnings (1), info (2), hints (3)
sc.settings.set_figure_params(dpi_save=300, facecolor="white", frameon=False, figsize=(15,15))
plt.rcParams['pdf.fonttype'] = 42
plt.rcParams['ps.fonttype'] = 42

# %matplotlib inline

# %%
adata=sc.read_h5ad('/nfs/team298/ls34/fibroblast_atlas_paper/final_adatas_chloecolours/adata_crosstissue_allcelltypes.h5ad') #+ ".subsampled")
# Out:
# /software/cellgen/team298/ls34/scpoli/lib/python3.11/site-packages/anndata/_core/anndata.py:1818: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")

# %% [markdown]
# # fig 6b

# %%
COLORS = {
    'Skin': "#90b0fe",# "#8ddae4",
    'Nasal mucosa': "#FF8000",
 #   'Skin SSc': "#c9a0dc",
    'Intestine': "#6BECBA",
    'Heart': "#8B0000",
    'Synovium': "#4A4A4A",
    'Endometrial':  "#ff9896",# "#FF66A1",
    'Lung':  "#F0E0D6",#"#E4D1B9",#"#8E4585",# "#E6E6FA", ##"#ffc658",#"#FFFFE0",  #¢"#9B59B6", #"#aa40fc",#"#c6b0d5",#"#FFFF00",#"#f4c2c2",  # Light pink for Lung
    "Lung_IPF (?HLCA repeat)": "#ffc658",# "#FFFFE0",  # ¢"#9B59B6", #"#aa40fc",# "#c6b0d5",#"#FFFF00",# "#f4c2c2", 
}
#ffc658
# COLORS = {
#     'Skin': "#A1C8F3",  # A softer blue, warmer and more sophisticated than the original #90b0fe
#     'Nasal mucosa': "#FF6F00",  # A toned-down bright orange, still vibrant but more refined than #FF8000
#     'Intestine': "#4ECDC4",  # A more muted turquoise, less harsh than #6BECBA but still fresh
#     'Heart': "#B22222",  # A deep, rich red that feels more mature and grounded compared to #8B0000
#     'Synovium': "#707070",  # A softer, warmer grey with a little more character than #4A4A4A
#     'Endometrial': "#FFB6B9",  # A gentler, muted pinkish shade, more balanced than #FF9896
#     'Lung': "#8E44AD",  # A deeper, more elegant purple compared to #9B59B6
#     "Lung_IPF (?HLCA repeat)": "#8E44AD",  # Same as 'Lung', keeping it consistent
# }

adata.obs["tissue"] = adata.obs["tissue"].astype("category")
adata.uns["tissue_colors"] = [COLORS[t] for t in adata.obs["tissue"].cat.categories]


sc.settings.set_figure_params(dpi=100,dpi_save=300, facecolor="white", frameon=False, figsize=(6, 6))
sc.pl.umap(
    adata,
    color="tissue",
    s=0.1,
    legend_fontsize=7,
    #save="fig7_all_crosstissue.pdf"

)

# %%
COLORS = {
    'Skin': "#90b0fe",# "#8ddae4",
    'Nasal mucosa': "#FF8000",
 #   'Skin SSc': "#c9a0dc",
    'Intestine': "#6BECBA",
    'Heart': "#8B0000",
    'Synovium': "#4A4A4A",
    'Endometrial':  "#ff9896",# "#FF66A1",
    'Lung':  "#fbc45a",# bRown#F0E0D6",#"#E4D1B9",#"#8E4585",# "#E6E6FA", ##"#ffc658",#"#FFFFE0",  #¢"#9B59B6", #"#aa40fc",#"#c6b0d5",#"#FFFF00",#"#f4c2c2",  # Light pink for Lung
    "Lung_IPF (?HLCA repeat)": "#ffc658",# "#FFFFE0",  # ¢"#9B59B6", #"#aa40fc",# "#c6b0d5",#"#FFFF00",# "#f4c2c2", 
}

adata.obs["tissue"] = adata.obs["tissue"].astype("category")
adata.uns["tissue_colors"] = [COLORS[t] for t in adata.obs["tissue"].cat.categories]

sc.settings.set_figure_params(dpi_save=300, facecolor="white", frameon=False, figsize=(15,15))

sc.pl.umap(
    adata,
    color="tissue",
    s=1,
    legend_fontsize=7,
    save="fig7_fbs_bytissue.pdf"

)

# %%
sc.settings.set_figure_params(dpi_save=300, facecolor="white", frameon=False, figsize=(2,2))
sc.pl.umap(
    adata,
    color=[
        "PDGFRA", "COL1A1", "LUM", "DCN",
    ],
    legend_loc="on data",
    s=1,
    legend_fontsize=7,ncols=1, cmap="Reds", vmax=5,
    save="fig7_fb_markers_crosstissue_singlerow.pdf"
)
